# %%
df = pd.read_csv("../data/raw/MachineLearningRating_v3.txt", sep="\t")

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("../data/raw/MachineLearningRating_v3.txt", sep="\t")
#       3 df.head()
#
# NameError: name 'pd' is not defined
